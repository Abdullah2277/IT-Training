# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score, root_mean_squared_error

# %% [markdown]
# ## Class Task

# %%
data = {'Size': [1500, 1800, 2200, 1200, 2000, 1600, 1900, 2300, 1300, 2100, 1700, 1850, 2250, 1250, 2050, 1550, 1750, 2150, 1350, 1950],
        'Bedrooms': [3, 4, 4, 2, 3, 3, 4, 4, 2, 3, 3, 4, 3, 2, 4, 3, 3, 4, 2, 3],
        'Bathrooms': [2, 3, 2, 1, 2, 2, 3, 3, 1, 2, 2, 2, 3, 1, 3, 2, 2, 3, 1, 2],
        'Lot_Size': [5000, 7000, 9000, 4000, 6000, 5500, 7500, 9500, 4500, 6500, 5200, 6800, 8800, 4200, 6200, 5100, 7200, 9200, 4300, 6300],
        'Age': [5, 10, 15, 2, 8, 6, 12, 18, 3, 9, 7, 11, 16, 4, 10, 5, 9, 14, 3, 7],
        'Price': [250000, 320000, 400000, 200000, 350000, 280000, 340000, 420000, 220000, 370000, 300000, 330000, 410000, 210000, 360000, 260000, 310000, 390000, 230000, 345000]}

df = pd.DataFrame(data)
df.head()
# Out:
#    Size  Bedrooms  Bathrooms  Lot_Size  Age   Price
# 0  1500         3          2      5000    5  250000
# 1  1800         4          3      7000   10  320000
# 2  2200         4          2      9000   15  400000
# 3  1200         2          1      4000    2  200000
# 4  2000         3          2      6000    8  350000

# %%
X = df.drop('Price',axis=1)
y = df['Price']

Xtrain,Xtest,ytrain,ytest = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
model = LinearRegression()
model.fit(Xtrain,ytrain)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(Xtest)

mse = mean_squared_error(ytest,y_pred)
rmse = root_mean_squared_error(ytest,y_pred)
r2 = r2_score(ytest,y_pred)

print(f"Mean Squared Error: {mse}")
print(f"Root Mean Squared Error: {rmse}")
print(f"R-squared: {r2}")
# Out:
# Mean Squared Error: 11872908.625697095
# Root Mean Squared Error: 3445.7087261834968
# R-squared: 0.9957118162977167

# %%
plt.scatter(ytest,y_pred)
plt.plot([ytest.min(),ytest.max()],[ytest.min(),ytest.max()],'r')
plt.xlabel("Actual Prices")
plt.ylabel("Predicted Prices")
plt.title("Actual Prices vs Predicted Prices")
plt.show()
